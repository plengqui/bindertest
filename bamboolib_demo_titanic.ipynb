# %% [markdown]
# # bamboolib demo
#
# ### How to get started
#
# 1. Watch the short demo video: https://www.youtube.com/watch?v=VUkRlt4HieY
#
# 2. Execute all cells and experiment with bamboolib yourself
#
# 3. Interested in using bamboolib on your own data? [Get started](https://bamboolib.com/get-started)
#
# ### Troubleshooting
#
# - If the ipython kernel becomes idle or you see a **Connection failed** popup, then please [launch a new Binder notebook](https://bamboolib.com/demo).
#
# If you have any other problem using bamboolib in this notebook, then please [send us an email](mailto:support@8080labs.com).

# %%
import pandas as pd
import bamboolib as bam
df = pd.read_csv("data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
! wget --no-check-certificate 'https://docs.google.com/uc?export=download&confirm=Zjzg&id=1PkWnDBJWPdoO3LMxe3Y7VH6LHYb9MBzn' -O find.txt
# Out:
# --2020-08-06 06:01:51--  https://docs.google.com/uc?export=download&confirm=Zjzg&id=1PkWnDBJWPdoO3LMxe3Y7VH6LHYb9MBzn
# Resolving docs.google.com (docs.google.com)... 172.217.16.142, 2a00:1450:4001:808::200e
# Connecting to docs.google.com (docs.google.com)|172.217.16.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘find.txt’
#
# find.txt                [ <=>                ]   3.19K  --.-KB/s    in 0s
#
# 2020-08-06 06:01:51 (23.6 MB/s) - ‘find.txt’ saved [3262]

# %%
with open("find.txt", encoding="utf-8") as f:
    for line in f.readlines():
        print(line)
# Out:
# <!DOCTYPE html><html><head><title>Google Drive - Virus scan warning</title><meta http-equiv="content-type" content="text/html; charset=utf-8"/><link href=&#47;static&#47;doclist&#47;client&#47;css&#47;4004094319&#45;untrustedcontent.css rel="stylesheet"><link rel="icon" href="https://ssl.gstatic.com/docs/doclist/images/infinite_arrow_favicon_4.ico"/><style nonce="926WHBccACVrbA2jKQeRTg">#gbar,#guser{font-size:13px;padding-top:0px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
#
# ...
